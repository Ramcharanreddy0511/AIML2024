# %%
import pandas as pd
df1=pd.read_excel("/content/student.xlsx")
df1
# Out:
#    SLNo Student Name  HT  CGPA
# 0     1     Praneeth  23  6.52
# 1     2      Aashish  20  7.52
# 2     3      Karthik  50  6.12
# 3     4      Sathwik  24  8.12

# %%
import pandas as pd
df2=pd.read_table("/content/student.txt")
df2
# Out:
#    SLNo Student Name  HT  CGPA
# 0     1     Praneeth  23  6.52
# 1     2      Aashish  20  7.52
# 2     3      Karthik  50  6.12
# 3     4      Sathwik  24  8.12

# %%
import pandas as pd
df3=pd.read_csv("/content/student.csv")
df3
# Out:
#    SLNo Student Name  HT  CGPA
# 0     1     Praneeth  23  6.52
# 1     2      Aashish  20  7.52
# 2     3      Karthik  50  6.12
# 3     4      Sathwik  24  8.12
